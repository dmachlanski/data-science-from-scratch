# %% [markdown]
# # Chapter 3 - Visualizing Data
# Let's discover some basics of matplotlib!
#
# We'll take a closer look at the following plot types:
# - Line chart
# - Bar chart
# - Scatterplot
#
# ## Getting started
# First, let's import 'pyplot' module from 'matplotlib'.

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# Then, let's create a simple line chart as a warm-up.

# %%
# Sample data
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

# Pass the data and apply some style
plt.plot(years, gdp, color='green', marker='o', linestyle='solid')

# Give the chart a title
plt.title("Nominal GDP")

# Add label to y-axis
plt.ylabel("Billions of $")

# Display the chart
plt.show()

# %% [markdown]
# ## Line charts
# Suitable for showing trends. Use plt.plot().

# %%
variance = [2 ** x for x in range(9)]
bias_squared = list(reversed(variance))
total_error = [x+y for x, y in zip(variance, bias_squared)]
xs = [i for i, _ in enumerate(variance)]

plt.plot(xs, variance, 'g-', label='variance')
plt.plot(xs, bias_squared, 'r-.', label='bias^2')
plt.plot(xs, total_error, 'b:', label='total error')

# Because labels have been defined already, we get a legend for free
# loc=9 means top-center
plt.legend(loc=9)
plt.xlabel("Model complexity")
plt.title("The Bias-Variance Tradeoff")
plt.show()

# %% [markdown]
# ## Bar charts
# Suitable to show how some quantity varies among some discrete set of items.

# %%
movies = ["Cloud Atlas", "Interstellar", "Hobbit", "Harry Potter", "Annihilation"]
num_oscars = [5, 11, 3, 8, 10]

# Build x-axis
xs = [i for i, _ in enumerate(movies)]

plt.bar(xs, num_oscars)
plt.ylabel("# of Academy Awards")
plt.title("My Favourite Movies")

# Position all the labels
plt.xticks(xs, movies)

plt.show()

# %% [markdown]
# ## Scatterplots
# Good for showing relationship between two paired sets of data.

# %%
grades1 = [99, 90, 85, 97, 80]
grades2 = [100, 85, 60, 90, 70]

plt.scatter(grades1, grades2)
plt.title("Relationship between two exams")
plt.xlabel("Test 1 grade")
plt.ylabel("Test 2 grade")

# Very important to get comparable axes
# Makes easier to notice, for instance, where most of the variation occurs (test 2)
plt.axis("equal")

plt.show()
